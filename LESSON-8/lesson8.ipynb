# %% [markdown]
# # LESSON 8

# %%
from pathlib import Path

file_path = Path.home() / "My_folder" / "My_File.txt"

print(file_path.exists())
print(file_path.name)        # My_File.txt
print(file_path.parent.name) # My_folder
# Out:
# False
# My_File.txt
# My_folder

# %%
from pathlib import Path

base = Path.cwd()
my_folder = base / "My_folder"
my_folder.mkdir(exist_ok="True")

(file1 := my_folder / "file1.txt").touch(exist_ok="True")
(file2 := my_folder / "file2.txt").touch(exist_ok="True")
