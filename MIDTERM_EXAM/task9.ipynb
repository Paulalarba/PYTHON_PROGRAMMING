# %% [markdown]
# # Q9

# %%
"""Task: Modules and Packages: Helpers. Create a package helpers/ with modules
string_utils.py (function shout(s) uppercases) and math_utils.py (function area(l,w)).
Then a main.py that imports with both import ... as ... and from ...
import .... Explain namespace collisions and why aliases help. Anchor concepts: modules, packages, import variations, namespaces. Reference: :contentReference[oaicite:15]index=15

Prompt: Create a Python package called helpers with two modules: string_utils.py containing a shout(s) function that converts strings to uppercase, 
and math_utils.py containing an area(l,w) function that calculates rectangle area. Then create a main.py that imports these using both "import ... as ..." and "from ... import ..." syntax. 
Explain what namespace collisions are and why using aliases with "import ... as ..." helps prevent them."""

# %%
"""ChatGPT Code
📁 Package Structure
helpers/
    __init__.py
    string_utils.py
    math_utils.py
main.py
.
"""
# helpers/string_utils.py
def shout(s: str) -> str:
    """
    Converts a string to uppercase.
    """
    return s.upper()

# helpers/math_utils.py
def area(l: float, w: float) -> float:
    """
    Calculates the area of a rectangle.
    """
    return l * w

# main.py
# Import modules using aliases
import helpers.string_utils as su
import helpers.math_utils as mu

# Import specific functions
from helpers.string_utils import shout
from helpers.math_utils import area

def main():
    # Using alias
    print("Using alias:", su.shout("hello world"))
    print("Using alias:", mu.area(5, 10))

    # Using direct import
    print("Direct import:", shout("python rocks"))
    print("Direct import:", area(3, 7))

if __name__ == "__main__":
    main()

# %%
"""• Correctness:
The code has a critical correctness issue - it fails to run due to an AttributeError. The helpers.string_utils module cannot find the shout function when imported with aliases,
 indicating a fundamental problem with the package structure or import mechanism.

• Complexity:
The package structure itself has minimal complexity, but the import failure suggests underlying issues with Python's module resolution that complicate the execution.

• Robustness:
The code is not robust as it fails to execute at all. The package structure appears correct on the surface, but there are hidden issues preventing proper module imports, 
likely related to Python path or package initialization.

• Readability:
The package structure is clearly documented with emojis and comments. The module separation is logical, and the main.py attempts to demonstrate both import styles. 
However, the execution failure undermines all readability benefits.

• Faithfulness:
While the code attempts to demonstrate package/module concepts and both import styles, 
the execution failure means it cannot faithfully illustrate the intended namespace collision prevention through aliases."""

# %%
"""correct code:
In the Task9 directory"""
